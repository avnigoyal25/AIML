# %% [markdown]
# # AI/ML and Data Science Assessment
#
# ## About the dataset
# The given is a dataset from the 1994 census. Your task is to perform Exploratory Data Analysis on this data and gain a better understanding on it.
#
# All the best on the assessment!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Q1. Your understanding about the following modules and their uses:
#
# 1. Numpy:
#
# 2. Pandas:
#
# 3. Matplotlib:

# %% [markdown]
# Q2. Read the data as a dataframe.

# %%
# Your code goes here
df=pd.read_csv('adult.csv.xls')

# %% [markdown]
# Q3 Find out the number of rows and columns in the data set

# %%
# Your code goes here
df.shape
# Out:
# (32561, 14)

# %% [markdown]
# Q4 Missing data is represented as a "?" in this dataset. Find the missing data and replace it with Nan.

# %%
# Your code goes here
df.replace('?',np.NaN)
# Out:
#        Age          Workclass    Education  Education-num  \
# 0       39          State-gov    Bachelors             13
# 1       50   Self-emp-not-inc    Bachelors             13
# 2       38            Private      HS-grad              9
# 3       53            Private         11th              7
# 4       28            Private    Bachelors             13
# ...    ...                ...          ...            ...
# 32556   27            Private   Assoc-acdm             12
# 32557   40            Private      HS-grad              9
# 32558   58            Private      HS-grad              9
# 32559   22            Private      HS-grad              9
# 32560   52       Self-emp-inc      HS-grad              9
#
#             marital status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# Q5 Find how many people have an income greater than 50k and how many less than 50k.

# %%
# Your code goes here
pd.value_counts(df['income'])
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %% [markdown]
# Q6 Find the ratio of male:female earning greater than 50k.

# %%
# Your code goes here
from fractions import Fraction
male= len(df[(df['income']=='>50k') and (df['sex'] =='Male')])
female= len(df[(df['income']=='>50k') and (df['sex'] =='Female')])
print(male,female)
#print("ratio of males/female earning greater than 50k is",Fraction(male/female))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Your code goes here
#       2 from fractions import Fraction
# ----> 3 male= len(df[(df['income']=='>50k') and (df['sex'] =='Male')])
#       4 female= len(df[(df['income']=='>50k') and (df['sex'] =='Female')])
#       5 print(male,female)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# Q7 Find out which occupation pays the highest.

# %%
#in this by plotting graph we came to know that Exec managerial pays the highest

# %%
# Your code goes here
plt.figure(figsize=(18,6))
sns.countplot(x=df['occupation'], hue = df['income'], palette='Greens_r')
plt.title('Income of Individuals of Different Occupations', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16,rotation=90)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# Q8 Plot a graph showing the distribution of income in different age groups. For example, how many people between the ages of 21-30 earn more than 50k and how many earn less than 50k. You have to plot one graph for all the age groups.

# %%
def age_group(x):
    x = int(x)
    x = abs(x)
    if( 18 < x < 31 ):
        return "19-30"
    if( 30 < x < 41 ):
        return "31-40"
    if( 40 < x < 51 ):
        return "41-50"
    if( 50 < x < 61 ):
        return "51-60"
    if( 60 < x < 71 ):
        return "61-70"
    else:
        return "Greater than 70"

df['age_group'] = df['Age'].apply(age_group)

# %%
# Your code goes here

plt.figure(figsize=(12,6))
order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(x=df['age_group'], hue = df['income'], palette='Greens_r', order = order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# Q9 Plot a similar graph for hours per week and income.

# %%
# Your code goes here
def hours(x):
    x = int(x)
    x = abs(x)
    if( 1 < x < 21 ):
        return "1-20"
    if( 20 < x < 41 ):
        return "21-40"
    if( 40 < x < 61 ):
        return "41-60"
    if( 60 < x < 81 ):
        return "61-80"
    else:
        return "Greater than 80"

df['hours'] = df['hours per week'].apply(hours)

# %%
plt.figure(figsize=(12,6))
order_list = ['1-20', '21-40', '41-60', '61-80', 'Greater than 80']
sns.countplot(x=df['hours'], hue = df['income'], palette='Greens_r', order = order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
